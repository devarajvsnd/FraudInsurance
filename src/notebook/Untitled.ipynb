# %%
import pandas as pd

# %%
df=pd.read_csv('F:\insurance_claims.csv')

# %%
null_columns = df.columns[df.isnull().all()]

# Drop columns with all null values
df=df.drop(null_columns, axis=1, inplace=True)

# %%
df
# Out:
#      months_as_customer  age    policy_number policy_bind_date policy_state  \
# 0                   328     48         521585       17-10-2014    OH
# 1                   228     42         342868       27-06-2006           IN
# 2                   134     29         687698       06-09-2000           OH
# 3                   256     41         227811       25-05-1990           IL
# 4                   228     44         367455       06-06-2014           IL
# ..                  ...    ...            ...              ...          ...
# 995                   3     38         941851       16-07-1991           OH
# 996                 285     41         186934       05-01-2014           IL
# 997                 130     34         918516       17-02-2003           OH
# 998                 458     62         533940       18-11-2011           IL
# 999                 456     60         556080       11-11-1996           OH
#
# ...

# %%
null_columns = df.columns[df.isnull().all()]

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age  ', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
for i in df.columns:
    if df.columns[i]

# %%
df.isnull().all()
# Out:
# months_as_customer             False
# age                            False
# policy_number                  False
# policy_bind_date               False
# policy_state                   False
# policy_csl                     False
# policy_deductable              False
# policy_annual_premium          False
# umbrella_limit                 False
# insured_zip                    False
# insured_sex                    False
# insured_education_level        False
# insured_occupation             False
# insured_hobbies                False
# insured_relationship           False
# capital-gains                  False
# capital-loss                   False
# incident_date                  False
# incident_type                  False
# collision_type                 False
# incident_severity              False
# authorities_contacted          False
# incident_state                 False
# incident_city                  False
# incident_location              False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
import numpy as np

# %%
df.isna()
# Out:
#      months_as_customer  age    policy_number  policy_bind_date  policy_state  \
# 0                 False  False          False             False         False
# 1                 False  False          False             False         False
# 2                 False  False          False             False         False
# 3                 False  False          False             False         False
# 4                 False  False          False             False         False
# ..                  ...    ...            ...               ...           ...
# 995               False  False          False             False         False
# 996               False  False          False             False         False
# 997               False  False          False             False         False
# 998               False  False          False             False         False
# 999               False  False          False             False         False
#
# ...

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df2=pd.read_csv("C:\\Users\\Devaraj\\Desktop\\Archive\\insurance_claims.csv")

# %%
df2
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
null_columns = df2.columns[df2.isnull().all()]

# %%
null_columns
# Out:
# Index(['_c39'], dtype='object')

# %%
df2.drop(null_columns, axis=1, inplace=True)

# %%
df2
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
columns = ["policy_bind_date","policy_state","policy_csl","insured_sex","insured_education_level",
                        "insured_occupation","insured_hobbies", "insured_relationship","incident_state",
                        "incident_date","incident_type", "collision_type","incident_severity",
                        "authorities_contacted","incident_city", "incident_location","property_damage",
                        "police_report_available","auto_make","auto_model", "fraud_reported"]

# %%
for col in columns:
    df2[col] = df2[col].apply(lambda x: "'" + str(x) + "'")

# %%
df2.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585     '2014-10-17'         'OH'
# 1                 228   42         342868     '2006-06-27'         'IN'
# 2                 134   29         687698     '2000-09-06'         'OH'
# 3                 256   41         227811     '1990-05-25'         'IL'
# 4                 228   44         367455     '2014-06-06'         'IL'
#
#    policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0   '250/500'               1000                1406.91               0
# 1   '250/500'               2000                1197.22         5000000
# 2   '100/300'               2000                1413.14         5000000
# 3   '250/500'               2000                1415.74         6000000
# 4  '500/1000'               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df2.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-82cb57e1f040> in <module>
# ----> 1 df2.type
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
import json

# %%
def read_json_file(file_path:str)->dict:
    """
    Reads a json file and returns the contents as a dictionary.
    file_path: str
    """
    with open(file_path, 'r') as json_file:
        return json.load(json_file)

# %%
json_path="F:\Fraud detection\config\schema.json"
json_info= read_json_file(json_path)

# %%
json_info
# Out:
# {'LengthOfDateStampInFile': 9,
#  'LengthOfTimeStampInFile': 6,
#  'NumberofColumns': 40,
#  'ColName': {'months_as_customer': 'Integer',
#   'age': 'Integer',
#   'policy_number': 'Integer',
#   'policy_bind_date': 'varchar',
#   'policy_state': 'varchar',
#   'policy_csl': 'varchar',
#   'policy_deductable': 'Integer',
#   'policy_annual_premium': 'Integer',
#   'umbrella_limit': 'Integer',
#   'insured_zip': 'Integer',
#   'insured_sex': 'varchar',
#   'insured_education_level': 'varchar',
#   'insured_occupation': 'varchar',
#   'insured_hobbies': 'varchar',
#   'insured_relationship': 'varchar',
#   'capital-gains': 'Integer',
#   'capital-loss': 'Integer',
#   'incident_date': 'varchar',
#   'incident_type': 'varchar',
#   'collision_type': 'varchar',
#   'incident_severity': 'varchar',
#   'authorities_contacted': 'varchar',
#   'incident_state': 'varchar',
#   'incident_city': 'varchar',
#   'incident_location': 'varchar',
#   'incident_hour_of_the_day': 'Integer',
# ...

# %%
json_info["columns_with_string_datatype"]
# Out:
# ['policy_bind_date',
#  'policy_state',
#  'policy_csl',
#  'insured_sex',
#  'insured_education_level',
#  'insured_occupation',
#  'insured_hobbies',
#  'insured_relationship',
#  'incident_state',
#  'incident_date',
#  'incident_type',
#  'collision_type',
#  'incident_severity',
#  'authorities_contacted',
#  'incident_city',
#  'incident_location',
#  'property_damage',
#  'police_report_available',
#  'auto_make',
#  'auto_model',
#  'fraud_reported']

# %%
json_info['columns_to remove']
# Out:
# ['policy_number',
#  'policy_bind_date',
#  'policy_state',
#  'insured_zip',
#  'incident_location',
#  'incident_date',
#  'incident_state',
#  'incident_city',
#  'insured_hobbies',
#  'auto_make',
#  'auto_model',
#  'auto_year',
#  'age',
#  'total_claim_amount']

# %%
["months_as_customer", "policy_deductable", "umbrella_limit",
                            "capital-gains", "capital-loss", "incident_hour_of_the_day",
                            "number_of_vehicles_involved", "bodily_injuries", "witnesses", "injury_claim",
                            "property_claim",
                            "vehicle_claim"]

# %%
num_df = df2[['months_as_customer', 'policy_deductable', 'umbrella_limit',
                            'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
                            'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'injury_claim',
                            'property_claim',
                            'vehicle_claim']]

# %%
num_df
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 0                   328               1000               0          53300
# 1                   228               2000         5000000              0
# 2                   134               2000         5000000          35100
# 3                   256               2000         6000000          48900
# 4                   228               1000         6000000          66000
# ..                  ...                ...             ...            ...
# 995                   3               1000               0              0
# 996                 285               1000               0          70900
# 997                 130                500         3000000          35100
# 998                 458               2000         5000000              0
# 999                 456               1000               0              0
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# ...

# %%
df2
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
 df2.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
columns_to_remove=["policy_number", "policy_bind_date", "policy_state","insured_zip", 
	"incident_location", "incident_date","incident_state", "incident_city", "insured_hobbies",
	"auto_make", "auto_model", "auto_year", "age", "total_claim_amount"]

# %%
columns_to_remove
# Out:
# ['policy_number',
#  'policy_bind_date',
#  'policy_state',
#  'insured_zip',
#  'incident_location',
#  'incident_date',
#  'incident_state',
#  'incident_city',
#  'insured_hobbies',
#  'auto_make',
#  'auto_model',
#  'auto_year',
#  'age',
#  'total_claim_amount']

# %%
useful_data=df2.drop(labels=columns_to_remove, axis=1)

# %%
useful_data
# Out:
#      months_as_customer policy_csl  policy_deductable  policy_annual_premium  \
# 0                   328    250/500               1000                1406.91
# 1                   228    250/500               2000                1197.22
# 2                   134    100/300               2000                1413.14
# 3                   256    250/500               2000                1415.74
# 4                   228   500/1000               1000                1583.91
# ..                  ...        ...                ...                    ...
# 995                   3   500/1000               1000                1310.80
# 996                 285    100/300               1000                1436.79
# 997                 130    250/500                500                1383.49
# 998                 458   500/1000               2000                1356.92
# 999                 456    250/500               1000                 766.19
#
# ...

# %%
useful_data.head()
# Out:
#    months_as_customer policy_csl  policy_deductable  policy_annual_premium  \
# 0                 328    250/500               1000                1406.91
# 1                 228    250/500               2000                1197.22
# 2                 134    100/300               2000                1413.14
# 3                 256    250/500               2000                1415.74
# 4                 228   500/1000               1000                1583.91
#
#    umbrella_limit insured_sex insured_education_level insured_occupation  \
# 0               0        MALE                      MD       craft-repair
# 1         5000000        MALE                      MD  machine-op-inspct
# 2         5000000      FEMALE                     PhD              sales
# 3         6000000      FEMALE                     PhD       armed-forces
# 4         6000000        MALE               Associate              sales
#
#   insured_relationship  capital-gains  ...  number_of_vehicles_involved  \
# ...

# %%
null_columns = useful_data.columns[useful_data.isnull().all()]
useful_data.drop(null_columns, axis=1, inplace=True)

# %%
useful_data
# Out:
#      months_as_customer policy_csl  policy_deductable  policy_annual_premium  \
# 0                   328    250/500               1000                1406.91
# 1                   228    250/500               2000                1197.22
# 2                   134    100/300               2000                1413.14
# 3                   256    250/500               2000                1415.74
# 4                   228   500/1000               1000                1583.91
# ..                  ...        ...                ...                    ...
# 995                   3   500/1000               1000                1310.80
# 996                 285    100/300               1000                1436.79
# 997                 130    250/500                500                1383.49
# 998                 458   500/1000               2000                1356.92
# 999                 456    250/500               1000                 766.19
#
# ...

# %%
useful_data.replace('?',np.NaN,inplace=True)

# %%
useful_data
# Out:
#      months_as_customer policy_csl  policy_deductable  policy_annual_premium  \
# 0                   328    250/500               1000                1406.91
# 1                   228    250/500               2000                1197.22
# 2                   134    100/300               2000                1413.14
# 3                   256    250/500               2000                1415.74
# 4                   228   500/1000               1000                1583.91
# ..                  ...        ...                ...                    ...
# 995                   3   500/1000               1000                1310.80
# 996                 285    100/300               1000                1436.79
# 997                 130    250/500                500                1383.49
# 998                 458   500/1000               2000                1356.92
# 999                 456    250/500               1000                 766.19
#
# ...

# %%
null_present = False
cols_with_missing_values=[]
cols = useful_data.columns

null_counts=useful_data.isna().sum() # check for the count of null values per column

for i in range(len(null_counts)):
    if null_counts[i]>0:
        null_present=True
        cols_with_missing_values.append(cols[i])

if(null_present): # write the logs to see which columns have null values
    dataframe_with_null = pd.DataFrame()
    dataframe_with_null['columns'] = useful_data.columns
    dataframe_with_null['missing values count'] = np.asarray(useful_data.isna().sum())

    dataframe_with_null.to_csv('null_values.csv')

# %%
cols
# Out:
# Index(['months_as_customer', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_relationship',
#        'capital-gains', 'capital-loss', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'injury_claim', 'property_claim',
#        'vehicle_claim', 'fraud_reported'],
#       dtype='object')

# %%
null_counts
# Out:
# months_as_customer               0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted            0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                360
# bodily_injuries                  0
# witnesses                        0
# police_report_available        343
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# fraud_reported                   0
# dtype: int64

# %%
len(null_counts)
# Out:
# 25

# %%
cols_with_missing_values
# Out:
# ['collision_type', 'property_damage', 'police_report_available']

# %%
dff=pd.read_csv(null_values.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-29742a24b87d> in <module>
# ----> 1 dff=pd.read_csv(null_values.csv)
#
# NameError: name 'null_values' is not defined

# %%
if(null_present): # write the logs to see which columns have null values
    dataframe_with_null = pd.DataFrame()
    dataframe_with_null['columns'] = useful_data.columns
    dataframe_with_null['missing values count'] = np.asarray(useful_data.isna().sum())

    dataframe_with_null.to_csv('null_values.csv')

# %%
dataframe_with_null
# Out:
#                         columns  missing values count
# 0            months_as_customer                     0
# 1                    policy_csl                     0
# 2             policy_deductable                     0
# 3         policy_annual_premium                     0
# 4                umbrella_limit                     0
# 5                   insured_sex                     0
# 6       insured_education_level                     0
# 7            insured_occupation                     0
# 8          insured_relationship                     0
# 9                 capital-gains                     0
# 10                 capital-loss                     0
# 11                incident_type                     0
# 12               collision_type                   178
# 13            incident_severity                     0
# 14        authorities_contacted                     0
# 15     incident_hour_of_the_day                     0
# ...

# %%
dataframe_with_null.to_csv('C:\\Users\\Devaraj\\Desktop\\Archive\\null_values.csv')

# %%
from sklearn.impute import SimpleImputer

# %%
df2
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
imputer = SimpleImputer(strategy='most_frequent')

imputed = pd.DataFrame(imputer.fit_transform(useful_data[cols_with_missing_values]), columns=cols_with_missing_values)

# %%
useful_data
# Out:
#      months_as_customer policy_csl  policy_deductable  policy_annual_premium  \
# 0                   328    250/500               1000                1406.91
# 1                   228    250/500               2000                1197.22
# 2                   134    100/300               2000                1413.14
# 3                   256    250/500               2000                1415.74
# 4                   228   500/1000               1000                1583.91
# ..                  ...        ...                ...                    ...
# 995                   3   500/1000               1000                1310.80
# 996                 285    100/300               1000                1436.79
# 997                 130    250/500                500                1383.49
# 998                 458   500/1000               2000                1356.92
# 999                 456    250/500               1000                 766.19
#
# ...

# %%
imputed
# Out:
#                    0    1    2
# 0     Side Collision  YES  YES
# 1     Rear Collision   NO   NO
# 2     Rear Collision   NO   NO
# 3    Front Collision   NO   NO
# 4     Rear Collision   NO   NO
# ..               ...  ...  ...
# 995  Front Collision  YES   NO
# 996   Rear Collision  YES   NO
# 997   Side Collision   NO  YES
# 998   Rear Collision   NO  YES
# 999   Rear Collision   NO   NO
#
# [1000 rows x 3 columns]

# %%
imputed
# Out:
#       collision_type property_damage police_report_available
# 0     Side Collision             YES                     YES
# 1     Rear Collision              NO                      NO
# 2     Rear Collision              NO                      NO
# 3    Front Collision              NO                      NO
# 4     Rear Collision              NO                      NO
# ..               ...             ...                     ...
# 995  Front Collision             YES                      NO
# 996   Rear Collision             YES                      NO
# 997   Side Collision              NO                     YES
# 998   Rear Collision              NO                     YES
# 999   Rear Collision              NO                      NO
#
# [1000 rows x 3 columns]

# %%
cat_df3 = useful_data.select_dtypes(include=['object']).copy()
cat_df3['policy_csl'] = cat_df3['policy_csl'].map({'100/300': 1, '250/500': 2.5, '500/1000': 5})
cat_df3['insured_education_level'] = cat_df3['insured_education_level'].map(
    {'JD': 1, 'High School': 2, 'College': 3, 'Masters': 4, 'Associate': 5, 'MD': 6, 'PhD': 7})
cat_df3['incident_severity'] = cat_df3['incident_severity'].map(
    {'Trivial Damage': 1, 'Minor Damage': 2, 'Major Damage': 3, 'Total Loss': 4})
cat_df3['insured_sex'] = cat_df3['insured_sex'].map({'FEMALE': 0, 'MALE': 1})
cat_df3['property_damage'] = cat_df3['property_damage'].map({'NO': 0, 'YES': 1})
cat_df3['police_report_available'] = cat_df3['police_report_available'].map({'NO': 0, 'YES': 1})

# %%
cat_df
# Out:
#      policy_csl  insured_sex  insured_education_level insured_occupation  \
# 0           2.5            1                        6       craft-repair
# 1           2.5            1                        6  machine-op-inspct
# 2           1.0            0                        7              sales
# 3           2.5            0                        7       armed-forces
# 4           5.0            1                        5              sales
# ..          ...          ...                      ...                ...
# 995         5.0            0                        4       craft-repair
# 996         1.0            0                        7     prof-specialty
# 997         2.5            0                        4       armed-forces
# 998         5.0            1                        5  handlers-cleaners
# 999         2.5            0                        5              sales
#
#     insured_relationship             incident_type   collision_type  \
# ...

# %%
cat_df.drop(columns=['collision_type', 'property_damage', 'police_report_available'], inplace=True)

# %%
cat_df
# Out:
#      policy_csl  insured_sex  insured_education_level insured_occupation  \
# 0           2.5            1                        6       craft-repair
# 1           2.5            1                        6  machine-op-inspct
# 2           1.0            0                        7              sales
# 3           2.5            0                        7       armed-forces
# 4           5.0            1                        5              sales
# ..          ...          ...                      ...                ...
# 995         5.0            0                        4       craft-repair
# 996         1.0            0                        7     prof-specialty
# 997         2.5            0                        4       armed-forces
# 998         5.0            1                        5  handlers-cleaners
# 999         2.5            0                        5              sales
#
#     insured_relationship             incident_type  incident_severity  \
# ...

# %%
cat_df['fraud_reported'] = cat_df['fraud_reported'].map({'N': 0, 'Y': 1})

# %%
cat_df
# Out:
#      policy_csl  insured_sex  insured_education_level insured_occupation  \
# 0           2.5            1                        6       craft-repair
# 1           2.5            1                        6  machine-op-inspct
# 2           1.0            0                        7              sales
# 3           2.5            0                        7       armed-forces
# 4           5.0            1                        5              sales
# ..          ...          ...                      ...                ...
# 995         5.0            0                        4       craft-repair
# 996         1.0            0                        7     prof-specialty
# 997         2.5            0                        4       armed-forces
# 998         5.0            1                        5  handlers-cleaners
# 999         2.5            0                        5              sales
#
#     insured_relationship             incident_type  incident_severity  \
# ...

# %%
cat_df.nunique()
# Out:
# policy_csl                  3
# insured_sex                 2
# insured_education_level     7
# insured_occupation         14
# insured_relationship        6
# incident_type               4
# incident_severity           4
# authorities_contacted       5
# fraud_reported              2
# dtype: int64

# %%
cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   policy_csl               1000 non-null   float64
#  1   insured_sex              1000 non-null   int64
#  2   insured_education_level  1000 non-null   int64
#  3   insured_occupation       1000 non-null   object
#  4   insured_relationship     1000 non-null   object
#  5   incident_type            1000 non-null   object
#  6   incident_severity        1000 non-null   int64
#  7   authorities_contacted    1000 non-null   object
#  8   fraud_reported           1000 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 70.4+ KB

# %%
object_columns = cat_df.select_dtypes(include='object').columns.tolist()

# %%
object_columns
# Out:
# ['insured_occupation',
#  'insured_relationship',
#  'incident_type',
#  'authorities_contacted']

# %%
cat_df[object_columns].nunique()
# Out:
# insured_occupation       14
# insured_relationship      6
# incident_type             4
# authorities_contacted     5
# dtype: int64

# %%
cat_df['insured_occupation'].unique()
# Out:
# array(['craft-repair', 'machine-op-inspct', 'sales', 'armed-forces',
#        'tech-support', 'prof-specialty', 'other-service',
#        'priv-house-serv', 'exec-managerial', 'protective-serv',
#        'transport-moving', 'handlers-cleaners', 'adm-clerical',
#        'farming-fishing'], dtype=object)

# %%
cols_to_drop = ['policy_csl', 'insured_education_level', 'incident_severity', 'insured_sex',
                                     'property_damage', 'police_report_available']

# %%
cols_to_drop
# Out:
# ['policy_csl',
#  'insured_education_level',
#  'incident_severity',
#  'insured_sex',
#  'property_damage',
#  'police_report_available']

# %%
for col in cat_df.drop(columns=cols_to_drop).columns:
    cat_df = pd.get_dummies(cat_df, columns=[col], prefix=[col], drop_first=True)

data.drop(columns=data.select_dtypes(include=['object']).columns, inplace=True)
data= pd.concat([cat_df, data],axis=1)

# %%
cat_df3
# Out:
#      policy_csl  insured_sex  insured_education_level insured_occupation  \
# 0           2.5            1                        6       craft-repair
# 1           2.5            1                        6  machine-op-inspct
# 2           1.0            0                        7              sales
# 3           2.5            0                        7       armed-forces
# 4           5.0            1                        5              sales
# ..          ...          ...                      ...                ...
# 995         5.0            0                        4       craft-repair
# 996         1.0            0                        7     prof-specialty
# 997         2.5            0                        4       armed-forces
# 998         5.0            1                        5  handlers-cleaners
# 999         2.5            0                        5              sales
#
#     insured_relationship             incident_type   collision_type  \
# ...

# %%
cat_df3.drop(cols_to_drop, axis=1, inplace=True)

# %%
cat_df3
# Out:
#     insured_occupation insured_relationship             incident_type  \
# 0         craft-repair              husband  Single Vehicle Collision
# 1    machine-op-inspct       other-relative             Vehicle Theft
# 2                sales            own-child   Multi-vehicle Collision
# 3         armed-forces            unmarried  Single Vehicle Collision
# 4                sales            unmarried             Vehicle Theft
# ..                 ...                  ...                       ...
# 995       craft-repair            unmarried  Single Vehicle Collision
# 996     prof-specialty                 wife  Single Vehicle Collision
# 997       armed-forces       other-relative   Multi-vehicle Collision
# 998  handlers-cleaners                 wife  Single Vehicle Collision
# 999              sales              husband                Parked Car
#
#       collision_type authorities_contacted fraud_reported
# 0     Side Collision                Police              Y
# ...

# %%
cols_to_drop=['policy_csl', 'insured_education_level', 'incident_severity', 'insured_sex',
                                            'property_damage', 'police_report_available', 'fraud_reported']

# %%
cat_df3['fraud_reported'] = cat_df3[''fraud_reported''].map({'N': 0, 'Y': 1})

# %%
cat_df3
# Out:
#     insured_occupation insured_relationship             incident_type  \
# 0         craft-repair              husband  Single Vehicle Collision
# 1    machine-op-inspct       other-relative             Vehicle Theft
# 2                sales            own-child   Multi-vehicle Collision
# 3         armed-forces            unmarried  Single Vehicle Collision
# 4                sales            unmarried             Vehicle Theft
# ..                 ...                  ...                       ...
# 995       craft-repair            unmarried  Single Vehicle Collision
# 996     prof-specialty                 wife  Single Vehicle Collision
# 997       armed-forces       other-relative   Multi-vehicle Collision
# 998  handlers-cleaners                 wife  Single Vehicle Collision
# 999              sales              husband                Parked Car
#
#       collision_type authorities_contacted  fraud_reported
# 0     Side Collision                Police               1
# ...

# %%
cat_df3.drop('fraud_reported', axis=1, inplace=True)

# %%
cat_df3
# Out:
#     insured_occupation insured_relationship             incident_type  \
# 0         craft-repair              husband  Single Vehicle Collision
# 1    machine-op-inspct       other-relative             Vehicle Theft
# 2                sales            own-child   Multi-vehicle Collision
# 3         armed-forces            unmarried  Single Vehicle Collision
# 4                sales            unmarried             Vehicle Theft
# ..                 ...                  ...                       ...
# 995       craft-repair            unmarried  Single Vehicle Collision
# 996     prof-specialty                 wife  Single Vehicle Collision
# 997       armed-forces       other-relative   Multi-vehicle Collision
# 998  handlers-cleaners                 wife  Single Vehicle Collision
# 999              sales              husband                Parked Car
#
#       collision_type authorities_contacted
# 0     Side Collision                Police
# ...

# %%
cat_df3.nunique()
# Out:
# insured_occupation       14
# insured_relationship      6
# incident_type             4
# collision_type            3
# authorities_contacted     5
# dtype: int64

# %%
for col in cat_df3.columns:
    cat_df3 = pd.get_dummies(self.cat_df, columns=[col], prefix=[col], drop_first=True)

data.drop(columns=self.data.select_dtypes(include=['object']).columns, inplace=True)
data= pd.concat([self.cat_df,self.data],axis=1)

# %%
cat_df3.columns[1]
# Out:
# 'insured_relationship'

# %%
for col in cat_df3.columns:
    cat_df3 = pd.get_dummies(cat_df3, columns=[col], prefix=[col], drop_first=True)

# %%
cat_df3
# Out:
#      insured_occupation_armed-forces  insured_occupation_craft-repair  \
# 0                                  0                                1
# 1                                  0                                0
# 2                                  0                                0
# 3                                  1                                0
# 4                                  0                                0
# ..                               ...                              ...
# 995                                0                                1
# 996                                0                                0
# 997                                1                                0
# 998                                0                                0
# 999                                0                                0
#
#      insured_occupation_exec-managerial  insured_occupation_farming-fishing  \
# ...
